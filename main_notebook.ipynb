# %% [markdown]
# # Use this notebook for your 3 choices of APIs
# In this lab you will choose 3 APIs from the list in the GitHub Repo
# Create a dataframe of the available data and think of a project that you could do with that data.
# Submit your notebook's repo link in the Student Portal.

# %% [markdown]
# ## Choice 1 | Brazilian Vehicles and Prices
#
# https://deividfortuna.github.io/fipe/
#
# Vehicles information from Fundação Instituto de Pesquisas Econômicas - Fipe
# A Tabela Fipe expressa preços médios de veículos no mercado nacional, servindo apenas como um parâmetro para negociações ou avaliações. Os preços efetivamente praticados variam em função da região, conservação, cor, acessórios ou qualquer outro fator que possa influenciar as condições de oferta e procura por um veículo específico

# %%
import requests
cars = requests.get('https://parallelum.com.br/fipe/api/v1/carros/marcas/59/modelos')
print("cars:", cars.status_code)
# Out:
# cars: 200

# %%
print(len(cars.content))
# print(cars.content)
# Out:
# 33978

# %%
import json
response = requests.get('https://parallelum.com.br/fipe/api/v1/carros/marcas/59/modelos')
results = response.json()
# results

# %%
import pandas as pd
data = response.json()
modelos = data['modelos']
df = pd.DataFrame(modelos)
df.head(20)
# Out:
#     codigo                                      nome
# 0     5585  AMAROK CD2.0 16V/S CD2.0 16V TDI 4x2 Die
# 1     5586  AMAROK CD2.0 16V/S CD2.0 16V TDI 4x4 Die
# 2     9895  AMAROK Comfor. 3.0 V6 TDI 4x4 Dies. Aut.
# 3     8531  AMAROK Comfor. CD 2.0 TDI 4x4 Dies. Aut.
# 4     5748  AMAROK CS2.0 16V/S2.0 16V TDI 4x2 Diesel
# 5     5749  AMAROK CS2.0 16V/S2.0 16V TDI 4x4 Diesel
# 6     8532   AMAROK Extreme CD 3.0 4x4 TB Dies. Aut.
# 7     7854  AMAROK Hig. Extreme CD 2.0 4x4 Dies. Aut
# 8     7674  AMAROK Hig.ULTIMATE CD 2.0 4x4 Dies. Aut
# 9     5940  AMAROK High.CD 2.0 16V TDI 4x4 Dies. Aut
# 10    5261  AMAROK Highline CD 2.0 16V TDI 4x4 Dies.
# 11    8183  AMAROK Highline CD 3.0 4x4 TB Dies. Aut.
# 12    5476       AMAROK SE CD 2.0 16V TDI 4x4 Diesel
# 13    7367  AMAROK T. Dark Label CD 2.0 4x4 Dies Aut
# 14    5350  AMAROK Trendline CD 2.0 16V TDI 4x4 Dies
# 15    6277  AMAROK Trendline CD 2.0 TDI 4X4 Dies Aut
# 16    2359                              Apolo GL 1.8
# ...

# %% [markdown]
# ## Choice 2 | The Final Space API
# https://finalspaceapi.com/docs/
#
# The final space API is based on the television show Final Space by Olan Rogers from TBS. From talking cats to evil aliens, the animated show tells the intergalactic adventures of Gary Goodspeed and his alien friend Mooncake as they unravel the mystery of "Final Space". The show can be viewed, amongst other places, on TBS, AdultSwim, and Netflix.
# All data of this API, such as character info, is obtained from the Final Space wiki. More data such as season and episode information is planned for future release. This data can be used for your own projects such as fan pages or any way you see fit.
# All this information is available through a RESTful API implemented in NodeJS. This API returns data in a friendly json format.
# The Final Space API is maintained as an open source project on GitHub. More information about contributing can be found in the readme.

# %%
import requests
fruits = requests.get('https://www.fruityvice.com/api/fruit/all')
print("fruits:", fruits.status_code)
# Out:
# fruits: 200

# %%
print(len(fruits.content))
# print(cars.content)
# Out:
# 7802

# %%
import json
response = requests.get('https://www.fruityvice.com/api/fruit/all')
results = response.json()
# results

# %%
import pandas as pd
data = response.json()
fruits = pd.DataFrame(data)
fruits.head(20)
# Out:
#             name  id           family             order       genus  \
# 0      Persimmon  52        Ebenaceae           Rosales   Diospyros
# 1     Strawberry   3         Rosaceae           Rosales    Fragaria
# 2         Banana   1         Musaceae      Zingiberales        Musa
# 3         Tomato   5       Solanaceae         Solanales     Solanum
# 4           Pear   4         Rosaceae           Rosales       Pyrus
# 5         Durian  60        Malvaceae          Malvales       Durio
# 6     Blackberry  64         Rosaceae           Rosales       Rubus
# 7    Lingonberry  65        Ericaceae          Ericales   Vaccinium
# 8           Kiwi  66    Actinidiaceae  Struthioniformes     Apteryx
# 9         Lychee  67      Sapindaceae        Sapindales      Litchi
# 10     Pineapple  10     Bromeliaceae            Poales      Ananas
# 11           Fig  68         Moraceae           Rosales       Ficus
# 12    Gooseberry  69  Grossulariaceae      Saxifragales       Ribes
# ...

# %%
def flatten(data, col_list):
    for column in col_list:
        flattened = pd.DataFrame(dict(data[column])).transpose()
        columns = [str(col) for col in flattened.columns]
        flattened.columns = [column + '_' + colname for colname in columns]
        data = pd.concat([data, flattened], axis=1)
        data = data.drop(column, axis=1)
    return data

# %%
nested_columns = ['nutritions']
fruits_df = flatten(fruits, nested_columns)
fruits_df.head()
# Out:
#          name  id      family         order      genus  nutritions_calories  \
# 0   Persimmon  52   Ebenaceae       Rosales  Diospyros                 81.0
# 1  Strawberry   3    Rosaceae       Rosales   Fragaria                 29.0
# 2      Banana   1    Musaceae  Zingiberales       Musa                 96.0
# 3      Tomato   5  Solanaceae     Solanales    Solanum                 74.0
# 4        Pear   4    Rosaceae       Rosales      Pyrus                 57.0
#
#    nutritions_fat  nutritions_sugar  nutritions_carbohydrates  \
# 0             0.0              18.0                      18.0
# 1             0.4               5.4                       5.5
# 2             0.2              17.2                      22.0
# 3             0.2               2.6                       3.9
# 4             0.1              10.0                      15.0
#
#    nutritions_protein
# 0                 0.0
# 1                 0.8
# 2                 1.0
# 3                 0.9
# ...

# %% [markdown]
# ## Choice 3 | games of thrones

# %%
import requests
gamesofthrones = requests.get('https://api.gameofthronesquotes.xyz/v1/characters')
print("finalspace:", gamesofthrones.status_code)
# Out:
# finalspace: 200

# %%
import json
response = requests.get('https://api.gameofthronesquotes.xyz/v1/characters')
gamesofthrones = response.json()
# gamesofthrones

# %%
import pandas as pd
data = response.json()
gamesofthrones = pd.DataFrame(data)
gamesofthrones.head()
# Out:
#                  name     slug  \
# 0            Jon Snow      jon
# 1         Sansa Stark    sansa
# 2  Eddard "Ned" Stark      ned
# 3       Catelyn Stark  catelyn
# 4     Jaime Lannister    jaime
#
#                                                house  \
# 0  {'slug': 'stark', 'name': 'House Stark of Wint...
# 1  {'slug': 'stark', 'name': 'House Stark of Wint...
# 2  {'slug': 'stark', 'name': 'House Stark of Wint...
# 3  {'slug': 'stark', 'name': 'House Stark of Wint...
# 4  {'slug': 'lannister', 'name': 'House Lannister...
#
#                                               quotes
# 0  [If I fall, don't bring me back., There is onl...
# 1  [I hate the king more than any of them., No ne...
# 2  [The man who passes the sentence should swing ...
# 3  [Laughter is poison to fear., All this horror ...
# 4  [The things I do for love., Fighting bravely f...

# %%
nested_columns = ['house']
gamesofthrones_df = flatten(gamesofthrones, nested_columns)
gamesofthrones_df.head(10)
# Out:
#                  name     slug  \
# 0            Jon Snow      jon
# 1         Sansa Stark    sansa
# 2  Eddard "Ned" Stark      ned
# 3       Catelyn Stark  catelyn
# 4     Jaime Lannister    jaime
# 5    Tyrion Lannister   tyrion
# 6    Cersei Lannister   cersei
# 7   Joffrey Baratheon  joffrey
# 8  Aerys II Targaryen    aerys
# 9     Aemon Targaryen    aemon
#
#                                               quotes house_slug  \
# 0  [If I fall, don't bring me back., There is onl...      stark
# 1  [I hate the king more than any of them., No ne...      stark
# 2  [The man who passes the sentence should swing ...      stark
# 3  [Laughter is poison to fear., All this horror ...      stark
# 4  [The things I do for love., Fighting bravely f...  lannister
# 5  [I have a tender spot in my heart for cripples...  lannister
# 6  [When you play the game of thrones, you win or...  lannister
# 7                     [Everyone is mine to torment.]  baratheon
# ...
